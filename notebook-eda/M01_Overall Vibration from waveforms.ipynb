# %%
# Import required libraries
import pandas as pd
import numpy as np
from scipy.stats import kurtosis as ss_kurtosis
import os, glob
import uuid

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 10000)

# %%
# Read waveform data samples
data_path = "../Data/Vibration-Data/" #Path to vibration CSVs
acc_wav_filenames = glob.glob(data_path + 'Pump4_PumpRadial/*td.csv')

# %%
acc_wav_filenames[0:5]
# Out:
# ['../Data/Vibration-Data/Pump4_PumpRadial\\g-pump-4_pump-radial_raw-data_2019-11-24_08-15-58_1480_td.csv',
#  '../Data/Vibration-Data/Pump4_PumpRadial\\g-pump-4_pump-radial_raw-data_2019-11-24_09-15-58_1480_td.csv',
#  '../Data/Vibration-Data/Pump4_PumpRadial\\g-pump-4_pump-radial_raw-data_2019-11-24_10-16-00_1480_td.csv',
#  '../Data/Vibration-Data/Pump4_PumpRadial\\g-pump-4_pump-radial_raw-data_2019-11-24_11-16-02_1480_td.csv',
#  '../Data/Vibration-Data/Pump4_PumpRadial\\g-pump-4_pump-radial_raw-data_2019-11-24_12-16-05_1480_td.csv']

# %%
# %%time
_files = acc_wav_filenames[0:10]
df_wav = pd.DataFrame()# define an empty dataframe
for file, i in zip(_files, range(1, len(_files)+1)):
    _name = 'sample_' + str(i)
    _tmp = pd.read_csv(file)
    _tmp['asset_id'] = 'Pump4'
    _tmp['asset_name'] = 'g-pump4'
    _tmp['datetime'] = 'datetime'+str(i)
    _tmp['direction'] = 'radial'
    _tmp['uuid'] = uuid.uuid4()
    _tmp.reset_index(drop = True, inplace = True)
    df_wav = pd.concat([df_wav, _tmp])
# Out:
# Wall time: 813 ms

# %%
# # Define aggregation rule here
# ops1 = [RMS, mean, peak, pk_pk, crest_factor, kurtosis] # Metrics to calculate on waveform amplitude
# aggregations = {}
# aggregations = dict.fromkeys(['y'], ops1)
# #aggregations.update(dict.fromkeys(['col_name1'], ops2))

# # Aggregate data and rename the columns.
# agg_df = pd.DataFrame() # Define a dataframe
# agg_df = df_.groupby([col_to_group_on],as_index=False).agg(aggregations)
# agg_df.columns = [x[1] if x[1]!='' else x[0] for x in agg_df.columns.ravel()]
# agg_df = pd.melt(agg_df, id_vars=['datetime'], value_vars=['RMS', 'mean', 'peak', 'pk_pk', 'crest_factor', 'kurtosis'],
#                  var_name='metric_name', value_name='metric_value')
# agg_df['asset_id'] = df_['asset_id'][0]
# agg_df['asset_name'] = df_['asset_name'][0]
# agg_df['param_name'] = 'overall-waveform'
# agg_df['metric_unit'] = metric_unit
# agg_df['metric_type'] = metric_type
# agg_df['direction'] = df_['direction'][0]
# agg_df['uuid'] = df_['uuid'][0]

# %%
# Define Function to aggrgate data
def func_to_aggregate_single_waveform(df_ , 
                               amp_col= 'y', 
                               col_to_group_on = 'uuid',
                               metric_unit = 'ms2',
                               metric_type = 'acceleration'
                              ):  
    # Define metric functions 
    def RMS(x):
        return np.sqrt(np.mean(np.square(x)))
    def mean(x):
        return np.mean(x)
    def peak(x):
        return np.max(np.abs(x))
    def pk_pk(x):
        return (np.max(x) - np.min(x))
    def crest_factor(x):
        return np.max(np.abs(x))/np.sqrt(np.mean(np.square(x)))
    def kurtosis(x):
        return ss_kurtosis(x, bias=False)

    # Define aggregation rule here
    ops1 = [RMS, mean, peak, pk_pk, crest_factor, kurtosis] # Metrics to calculate on waveform amplitude
    aggregations = {}
    aggregations = dict.fromkeys(['y'], ops1)
    #aggregations.update(dict.fromkeys(['col_name1'], ops2))
    
    # Aggregate data and rename the columns.
    agg_df = pd.DataFrame() # Define a dataframe
    df_.reset_index(drop=True, inplace=True)
    agg_df = df_.groupby([col_to_group_on], as_index=False).agg(aggregations)
    agg_df.columns = [x[1] if x[1]!='' else x[0] for x in agg_df.columns.ravel()]
    agg_df = pd.melt(agg_df, id_vars=['datetime'], value_vars=['RMS', 'mean', 'peak', 'pk_pk', 'crest_factor', 'kurtosis'],
                 var_name='metric_name', value_name='metric_value')
    agg_df['asset_id'] = df_['asset_id'][0]
    agg_df['asset_name'] = df_['asset_name'][0]
    agg_df['param_name'] = 'overall-waveform'
    agg_df['metric_unit'] = metric_unit
    agg_df['metric_type'] = metric_type
    agg_df['direction'] = df_['direction'][0]
    agg_df['uuid'] = df_['uuid'][0]
    return agg_df

# %%
def func_to_aggregate_overall_wavform(df_waveforms , # Wavrform df consisting 
                                      amp_col= 'y',  # amplitude column name in waveform
                                      col_to_group_on = 'datetime', # Columns to apply groupby on 
                                      metric_unit = 'ms2', # unit of the waveform
                                      metric_type = 'acceleration' # type of waveform
                                      ):
    df_overall_wavform = pd.DataFrame()
    for _id in df_wav[col_to_group_on].unique():
        df_ = df_waveforms[df_waveforms[col_to_group_on]==_id].reset_index(drop = True).copy(deep=False)
        print(df_.shape)
        df_1 = func_to_aggregate_single_waveform(df_, amp_col, col_to_group_on, metric_unit, metric_type)
        df_overall_wavform = pd.concat([df_overall_wavform, df_1])
    df_overall_wavform.reset_index(drop = True, inplace = True)
    return df_overall_wavform

# %%
# func_to_aggregate_single_waveform(df_, amp_col, col_to_group_on, metric_unit, metric_type)

# %%
func_to_aggregate_overall_wavform(df_wav)
# Out:
# (65536, 7)
# (65536, 7)
# (65536, 7)
# (65536, 7)
# (65536, 7)
# (65536, 7)
# (65536, 7)
# (65536, 7)
# (65536, 7)
# (65536, 7)
#       datetime   metric_name  metric_value asset_id asset_name        param_name metric_unit   metric_type direction                                  uuid
# 0    datetime1           RMS      7.015961    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  fc74b6be-bfe5-4ebd-8360-ea8d9477933a
# 1    datetime1          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  fc74b6be-bfe5-4ebd-8360-ea8d9477933a
# 2    datetime1          peak     26.465051    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  fc74b6be-bfe5-4ebd-8360-ea8d9477933a
# 3    datetime1         pk_pk     52.542109    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  fc74b6be-bfe5-4ebd-8360-ea8d9477933a
# 4    datetime1  crest_factor      3.772121    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  fc74b6be-bfe5-4ebd-8360-ea8d9477933a
# 5    datetime1      kurtosis     -0.240132    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  fc74b6be-bfe5-4ebd-8360-ea8d9477933a
# 6    datetime2           RMS      7.041456    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  8354dfa3-fa31-44e2-923d-fa64019d3d66
# 7    datetime2          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  8354dfa3-fa31-44e2-923d-fa64019d3d66
# 8    datetime2          peak     27.904744    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  8354dfa3-fa31-44e2-923d-fa64019d3d66
# 9    datetime2         pk_pk     54.764730    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  8354dfa3-fa31-44e2-923d-fa64019d3d66
# 10   datetime2  crest_factor      3.962923    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  8354dfa3-fa31-44e2-923d-fa64019d3d66
# 11   datetime2      kurtosis     -0.180446    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  8354dfa3-fa31-44e2-923d-fa64019d3d66
# 12   datetime3           RMS      6.888933    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  7cdb3865-00f0-41e0-80e1-c1255fd661bd
# 13   datetime3          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  7cdb3865-00f0-41e0-80e1-c1255fd661bd
# 14   datetime3          peak     26.752478    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  7cdb3865-00f0-41e0-80e1-c1255fd661bd
# 15   datetime3         pk_pk     52.799822    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  7cdb3865-00f0-41e0-80e1-c1255fd661bd
# 16   datetime3  crest_factor      3.883400    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  7cdb3865-00f0-41e0-80e1-c1255fd661bd
# 17   datetime3      kurtosis     -0.163355    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  7cdb3865-00f0-41e0-80e1-c1255fd661bd
# 18   datetime4           RMS      6.729500    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  05a677b9-6091-44c8-8b06-6c37e9518641
# 19   datetime4          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  05a677b9-6091-44c8-8b06-6c37e9518641
# 20   datetime4          peak     25.558130    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  05a677b9-6091-44c8-8b06-6c37e9518641
# 21   datetime4         pk_pk     50.516859    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  05a677b9-6091-44c8-8b06-6c37e9518641
# 22   datetime4  crest_factor      3.797924    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  05a677b9-6091-44c8-8b06-6c37e9518641
# 23   datetime4      kurtosis     -0.146710    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  05a677b9-6091-44c8-8b06-6c37e9518641
# 24   datetime5           RMS      6.739123    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70dd7058-c393-4f2e-b945-3e25dbbb1248
# 25   datetime5          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70dd7058-c393-4f2e-b945-3e25dbbb1248
# 26   datetime5          peak     26.780910    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70dd7058-c393-4f2e-b945-3e25dbbb1248
# 27   datetime5         pk_pk     51.717426    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70dd7058-c393-4f2e-b945-3e25dbbb1248
# 28   datetime5  crest_factor      3.973946    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70dd7058-c393-4f2e-b945-3e25dbbb1248
# 29   datetime5      kurtosis     -0.134214    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70dd7058-c393-4f2e-b945-3e25dbbb1248
# 30   datetime6           RMS      6.658520    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  ddb495aa-dec9-47ee-b788-6f665ce8c75c
# 31   datetime6          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  ddb495aa-dec9-47ee-b788-6f665ce8c75c
# 32   datetime6          peak     26.804277    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  ddb495aa-dec9-47ee-b788-6f665ce8c75c
# 33   datetime6         pk_pk     52.613766    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  ddb495aa-dec9-47ee-b788-6f665ce8c75c
# 34   datetime6  crest_factor      4.025561    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  ddb495aa-dec9-47ee-b788-6f665ce8c75c
# 35   datetime6      kurtosis     -0.124711    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  ddb495aa-dec9-47ee-b788-6f665ce8c75c
# 36   datetime7           RMS      6.779569    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  b480bca0-f8fc-4831-a274-b2f26f9d6891
# 37   datetime7          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  b480bca0-f8fc-4831-a274-b2f26f9d6891
# 38   datetime7          peak     26.525853    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  b480bca0-f8fc-4831-a274-b2f26f9d6891
# 39   datetime7         pk_pk     51.728740    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  b480bca0-f8fc-4831-a274-b2f26f9d6891
# 40   datetime7  crest_factor      3.912616    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  b480bca0-f8fc-4831-a274-b2f26f9d6891
# 41   datetime7      kurtosis     -0.146880    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  b480bca0-f8fc-4831-a274-b2f26f9d6891
# 42   datetime8           RMS      6.931731    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70f357f0-0d19-4419-894e-fe4daae73372
# 43   datetime8          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70f357f0-0d19-4419-894e-fe4daae73372
# 44   datetime8          peak     28.411235    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70f357f0-0d19-4419-894e-fe4daae73372
# 45   datetime8         pk_pk     54.408960    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70f357f0-0d19-4419-894e-fe4daae73372
# 46   datetime8  crest_factor      4.098721    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70f357f0-0d19-4419-894e-fe4daae73372
# 47   datetime8      kurtosis     -0.114091    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  70f357f0-0d19-4419-894e-fe4daae73372
# 48   datetime9           RMS      6.738178    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  21013fe8-c64a-4fa2-af18-5d8bb0795bfc
# 49   datetime9          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  21013fe8-c64a-4fa2-af18-5d8bb0795bfc
# 50   datetime9          peak     28.346278    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  21013fe8-c64a-4fa2-af18-5d8bb0795bfc
# 51   datetime9         pk_pk     52.342224    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  21013fe8-c64a-4fa2-af18-5d8bb0795bfc
# 52   datetime9  crest_factor      4.206816    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  21013fe8-c64a-4fa2-af18-5d8bb0795bfc
# 53   datetime9      kurtosis     -0.172306    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  21013fe8-c64a-4fa2-af18-5d8bb0795bfc
# 54  datetime10           RMS      6.859275    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  a100add4-ec5a-46fb-a3f8-5dba5349c98f
# 55  datetime10          mean      0.003129    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  a100add4-ec5a-46fb-a3f8-5dba5349c98f
# 56  datetime10          peak     30.408730    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  a100add4-ec5a-46fb-a3f8-5dba5349c98f
# 57  datetime10         pk_pk     57.957862    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  a100add4-ec5a-46fb-a3f8-5dba5349c98f
# 58  datetime10  crest_factor      4.433228    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  a100add4-ec5a-46fb-a3f8-5dba5349c98f
# 59  datetime10      kurtosis     -0.130417    Pump4    g-pump4  overall-waveform         ms2  acceleration    radial  a100add4-ec5a-46fb-a3f8-5dba5349c98f
